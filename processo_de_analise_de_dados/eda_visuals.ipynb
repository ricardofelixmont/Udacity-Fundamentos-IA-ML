# %% [markdown]
# # EDA com visualizações
# Crie visualizações para resopnder as perguntas do teste abaixo deste notebook.

# %%
# Carregue o conjunto de dados
import pandas as pd
# %matplotlib inline

df = pd.read_csv('winequality_edited.csv')
df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   red
# 1      9.8        5   red
# ...

# %% [markdown]
# ### Histogramas para diversas características

# %%
df['fixed_acidity'].plot(kind='hist');

# %%
df['total_sulfur_dioxide'].plot(kind='hist');

# %%
df['pH'].plot(kind='hist')

# %% [markdown]
# Com base nos histogramas das colunas deste conjunto de dados, quais variáveis de características aparecem deslocadas para a direita?
#
# Resposta: `acidez fixa`e `Álcool`

# %%
df['alcohol'].plot(kind='hist')

# %% [markdown]
# ### Diagrama de dispersão da qualidade associada a diversas características

# %%
df.plot(x='volatile_acidity', y='quality', kind='scatter')

# %%
df.plot(x='total_sulfur_dioxide', y='quality', kind='scatter')

# %%
df.plot(x='pH', y='quality', kind='scatter')

# %%
df.plot(x='alcohol', y='quality', kind='scatter')

# %% [markdown]
# Apesar de não ficar totalmente claro, conforme o valor de alcohol aumeta, temos uma tendência a aumentar a qualidade. Podemos ver como o deslocamento das linhas da qualidade para a direita.
