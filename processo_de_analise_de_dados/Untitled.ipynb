# %% [markdown]
# ## Processo de Alise de Dados
#     Lendo arquivos csv com Pandas

# %% [markdown]
# Podemos colocar o parâmetro sep no método `read_csv` como visto abaixo:
# O método head() pode levar como argumento a quantidade de linhas que queremos previsualizar.

# %%
import pandas as pd

arquivo = pd.read_csv('chicago.csv', sep=',')

arquivo.head(10)
# Out:
#             Start Time             End Time  Trip Duration  \
# 0  2017-01-01 00:00:36  2017-01-01 00:06:32            356
# 1  2017-01-01 00:02:54  2017-01-01 00:08:21            327
# 2  2017-01-01 00:06:06  2017-01-01 00:18:31            745
# 3  2017-01-01 00:07:28  2017-01-01 00:12:51            323
# 4  2017-01-01 00:07:57  2017-01-01 00:20:53            776
# 5  2017-01-01 00:10:44  2017-01-01 00:21:27            643
# 6  2017-01-01 00:11:34  2017-01-01 00:23:47            733
# 7  2017-01-01 00:14:57  2017-01-01 00:26:22            685
# 8  2017-01-01 00:15:03  2017-01-01 00:26:28            685
# 9  2017-01-01 00:17:01  2017-01-01 00:29:49            768
#
#                           Start Station                   End Station  \
# 0                  Canal St & Taylor St      Canal St & Monroe St (*)
# 1            Larrabee St & Menomonee St  Sheffield Ave & Kingsbury St
# 2  Orleans St & Chestnut St (NEXT Apts)    Ashland Ave & Blackhawk St
# ...

# %% [markdown]
# ## Cabeçalhos
#
#     Podemos escolher qual linha do csv será o cabeçalho, como no caso abaixo que escolhi a 2° linha do arquivo para ser o cabeçalho:

# %%
arquivo = pd.read_csv('chicago.csv', header=2)
arquivo.head()
# Out:
#    2017-01-01 00:02:54  2017-01-01 00:08:21  327  \
# 0  2017-01-01 00:06:06  2017-01-01 00:18:31  745
# 1  2017-01-01 00:07:28  2017-01-01 00:12:51  323
# 2  2017-01-01 00:07:57  2017-01-01 00:20:53  776
# 3  2017-01-01 00:10:44  2017-01-01 00:21:27  643
# 4  2017-01-01 00:11:34  2017-01-01 00:23:47  733
#
#              Larrabee St & Menomonee St Sheffield Ave & Kingsbury St  \
# 0  Orleans St & Chestnut St (NEXT Apts)   Ashland Ave & Blackhawk St
# 1               Franklin St & Monroe St       Clinton St & Tilden St
# 2                  Broadway & Barry Ave      Sedgwick St & North Ave
# 3                  State St & Kinzie St           Wells St & Polk St
# 4                Wabash Ave & Wacker Pl       Clinton St & Tilden St
#
#    Subscriber  Male  1984.0
# 0  Subscriber  Male  1985.0
# 1  Subscriber  Male  1990.0
# 2  Subscriber  Male  1990.0
# 3  Subscriber  Male  1970.0
# 4  Subscriber  Male  1986.0
